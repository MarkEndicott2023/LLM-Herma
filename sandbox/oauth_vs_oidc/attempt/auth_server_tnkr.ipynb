# %%
import secrets
import mini_jwt
# Out:
# ALL THINGS PASS!

# %%
dir(mini_jwt)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'b64url_decode',
#  'b64url_encode',
#  'base64',
#  'decode_payload_UNVERIFIED',
#  'encode',
#  'hashlib',
#  'hmac',
#  'is_jwt',
#  'json',
#  'now',
#  'time',
#  'tok',
#  'verify_signature']
